# %% [markdown]
# # News Headlines Sentiment
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\abdul\anaconda3\envs\pyvizenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
# Read your api key environment variable
load_dotenv()
news_api_key = os.getenv("news_api")

# %%
# Create a newsapi client
from newsapi import NewsApiClient
news_api= NewsApiClient(api_key = news_api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_headlines = news_api.get_everything(
    q="bitcoin",language="en",page_size=100,sort_by="relevancy")

# %%
# Fetch the Ethereum news articles
# YOUR CODE HERE!
ethereum_headlines = news_api.get_everything(
    q="ethereum",language="en",page_size=100,sort_by="relevancy")

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_sentiments = []

for article in bitcoin_headlines['articles']:
    try:
        text = article['content']
        date = article['publishedAt'][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment['compound']
        pos = sentiment['pos']
        neu = sentiment['neu']
        neg = sentiment['neg']
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
        })
        
    except AttributeError:
        pass
    

#Construct a dataframe    
bitcoin_df=  pd.DataFrame(bitcoin_sentiments)
# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
bitcoin_df = bitcoin_df[cols]

bitcoin_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-04-27  Tesla’s relationship with bitcoin is not a dal...    0.0000
# 1  2021-04-20  Cryptocurrency continues to gain mainstream ac...    0.7506
# 2  2021-04-23  Cryptocurrency prices continued to tumble Frid...    0.0000
# 3  2021-04-13  The crypto industry as a whole has seen a mome...    0.6124
# 4  2021-04-27  image copyrightGetty Images\r\nimage captionEl...    0.7003
#
#    positive  negative  neutral
# 0     0.000       0.0    1.000
# 1     0.171       0.0    0.829
# 2     0.000       0.0    1.000
# 3     0.135       0.0    0.865
# 4     0.167       0.0    0.833

# %%
# Create the ethereum sentiment scores DataFrame
ethereum_sentiments = []

for article in ethereum_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
ethereum_df = pd.DataFrame(ethereum_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
ethereum_df = ethereum_df[cols]

ethereum_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-04-20  Cryptocurrency continues to gain mainstream ac...    0.7506
# 1  2021-04-20  Venmo is jumping aboard the cryptocurrency ban...    0.0258
# 2  2021-05-01  New York (CNN Business)Bitcoin prices continue...    0.0000
# 3  2021-04-13  ConsenSys, a key player in crypto and a major ...    0.2732
# 4  2021-05-03  A representation of virtual currency Ethereum ...    0.0000
#
#    positive  negative  neutral
# 0     0.171       0.0    0.829
# 1     0.034       0.0    0.966
# 2     0.000       0.0    1.000
# 3     0.062       0.0    0.938
# 4     0.000       0.0    1.000

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.113001    0.057620    0.027540    0.914850
# std      0.355306    0.068003    0.045913    0.083439
# min     -0.680800    0.000000    0.000000    0.662000
# 25%      0.000000    0.000000    0.000000    0.849750
# 50%      0.000000    0.033500    0.000000    0.922000
# 75%      0.371025    0.100750    0.058500    1.000000
# max      0.812600    0.269000    0.219000    1.000000

# %%
# Describe the Ethereum Sentiment
ethereum_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.121232    0.057480    0.027250    0.915280
# std      0.366322    0.069126    0.047425    0.081849
# min     -0.918600    0.000000    0.000000    0.694000
# 25%      0.000000    0.000000    0.000000    0.842750
# 50%      0.000000    0.034000    0.000000    0.931000
# 75%      0.360375    0.100500    0.049250    1.000000
# max      0.827100    0.256000    0.289000    1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A:  Ethereum had a slightly higher mean positive score. (.0597 compared to .0576)
#
# Q: Which coin had the highest compound score?
#
# A: The coin with the highest compound score is also ethereum. (.8271 compared to .8126)
#
# Q. Which coin had the highest positive score?
#
# A: bitcoin had the highest positive score. (.269 compared to .256)

# %% [markdown]
# ---

# %% [markdown]
# # Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re
lemmatizer = WordNetLemmatizer()

# %%
# Expand the default stopwords list if necessary
# YOUR CODE HERE!

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""

    #remove stop words
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    # Remove the punctuation
    re_clean = regex.sub('', text)
    words = word_tokenize(re_clean)
    # Lemmatize Words into root words then convert into Lowercase
    lem = [lemmatizer.lemmatize(word) for word in words]
    tokens = [word.lower() for word in lem if word.lower() not in sw]
    return tokens

# %%
# Create a new tokens column for bitcoin
bitcoin_df["tokens"] = bitcoin_df["text"].apply(tokenizer)
bitcoin_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-04-27  Tesla’s relationship with bitcoin is not a dal...    0.0000
# 1  2021-04-20  Cryptocurrency continues to gain mainstream ac...    0.7506
# 2  2021-04-23  Cryptocurrency prices continued to tumble Frid...    0.0000
# 3  2021-04-13  The crypto industry as a whole has seen a mome...    0.6124
# 4  2021-04-27  image copyrightGetty Images\r\nimage captionEl...    0.7003
#
#    positive  negative  neutral  \
# 0     0.000       0.0    1.000
# 1     0.171       0.0    0.829
# 2     0.000       0.0    1.000
# 3     0.135       0.0    0.865
# 4     0.167       0.0    0.833
#
#                                               tokens
# 0  [teslas, relationship, bitcoin, dalliance, acc...
# 1  [cryptocurrency, continues, gain, mainstream, ...
# 2  [cryptocurrency, price, continued, tumble, fri...
# 3  [crypto, industry, whole, ha, seen, momentous,...
# 4  [image, copyrightgetty, imagesimage, captionel...

# %%
# Create a new tokens column for ethereum
ethereum_df["tokens"] = ethereum_df["text"].apply(tokenizer)
ethereum_df.tail()
# Out:
#           date                                               text  compound  \
# 95  2021-04-23  Global shares steadied on Friday around 1% bel...    0.0000
# 96  2021-04-27  (Reuters) - Evolving rules, environmental conc...   -0.4767
# 97  2021-04-28  The MSCI logo is seen in this June 20, 2017 il...    0.2960
# 98  2021-04-28  * Asian stock markets: tmsnrt.rs/2zpUAr4\r\n* ...    0.4678
# 99  2021-04-30  U.S. one hundred dollar notes are seen in this...    0.2263
#
#     positive  negative  neutral  \
# 95     0.097     0.070    0.833
# 96     0.052     0.148    0.800
# 97     0.135     0.071    0.794
# 98     0.111     0.049    0.840
# 99     0.060     0.000    0.940
#
#                                                tokens
# 95  [global, share, steadied, friday, around, reco...
# 96  [reuters, evolving, rule, environmental, conce...
# 97  [msci, logo, seen, june, illustration, photo, ...
# 98  [asian, stock, market, tmsnrtrszpuar, equities...
# 99  [us, one, hundred, dollar, note, seen, picture...

# %% [markdown]
# ---

# %% [markdown]
# # NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
# YOUR CODE HERE!
bigrams = ngrams(tokenizer(bitcoin_df["text"].str.cat()), 2)

#bigrams_df= pd.DataFrame(bigrams)
#bigrams_df.head()

# %%
# Generate the Ethereum N-grams where N=2
eth_grams = ngrams(tokenizer(ethereum_df["text"].str.cat()), 2)

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Get the top 10 words for Bitcoin
# YOUR CODE HERE!
bitcoin_tokens= tokenizer(bitcoin_df["text"].str.cat())
token_count(bitcoin_tokens, 10)
# Out:
# [('bitcoin', 65),
#  ('reuters', 33),
#  ('cryptocurrency', 27),
#  ('ha', 19),
#  ('charsby', 19),
#  ('currency', 17),
#  ('seen', 17),
#  ('stock', 16),
#  ('said', 14),
#  ('first', 13)]

# %%
# Get the top 10 words for Ethereum
ethereum_tokens= tokenizer(ethereum_df["text"].str.cat())
token_count(ethereum_tokens, 10)
# Out:
# [('cryptocurrency', 30),
#  ('bitcoin', 30),
#  ('ha', 18),
#  ('reuters', 18),
#  ('ethereum', 15),
#  ('crypto', 15),
#  ('high', 14),
#  ('digital', 14),
#  ('currency', 13),
#  ('first', 13)]

# %% [markdown]
# # Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud and save photo
from path import Path
bitcoin_wc = WordCloud().generate(str(bitcoin_tokens))
plt.imshow(bitcoin_wc)
plt.axis("off")
plt.title("Bitcoin Word Cloud")
bitcoin_wc.to_file(Path('Images/bitcoin_wc.png'))

# %%
# Generate the Ethereum word cloud
ethereum_wc = WordCloud().generate(str(ethereum_tokens))
plt.imshow(ethereum_wc)
plt.axis("off")
plt.title("Ethereum Word Cloud")
ethereum_wc.to_file(Path("Images/ethereum_wc.png"))

# %% [markdown]
# # Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both coins and visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Optional - download a language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Bitcoin NER

# %%
# Concatenate all of the bitcoin text together
bitcoin_text= bitcoin_df["text"].str.cat()
#bitcoin_text

# %%
# Run the NER processor on all of the text
bitcoin_ner = nlp(bitcoin_text)

# Add a title to the document
bitcoin_ner.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
# YOUR CODE HERE!
displacy.render(bitcoin_ner, style = 'ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Tesla’s relationship with bitcoin is not a dalliance, according to the comments made by the company’s
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CFO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and dubbed “master of coin”
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zach Kirkhorn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  during an earnings call
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Instead, the compan… [+3073 chars]Cryptocurrency continues to gain mainstream acceptance, as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PayPal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  announced that they have added
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin, Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin Cash
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Litecoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to its
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Venmo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  app. With a user base of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     70 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , the mo… [+2782 chars]Cryptocurrency prices continued to tumble
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  with
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  leading the charge, with prices for the internet currency dipping below $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     50,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  for the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  time since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     early March
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is down ro… [+1222 chars]The crypto industry as a whole has seen
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a momentous year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of growth, heavily spurred on by the entrance of institutional investors adopting bitcoin due to its store of value properties. The
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>image captionElon
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has posted
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  profits of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $438m
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  (£
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     315
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# m) bolstered by sales of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height:

# %%
# List all Entities
# YOUR CODE HERE!
for ent in bitcoin_ner.ents:
    print(ent.text, ent.label_)
# Out:
# CFO ORG
# Zach Kirkhorn PERSON
# Monday DATE
# PayPal ORG
# Bitcoin, Ethereum ORG
# Bitcoin Cash PERSON
# Litecoin PERSON
# Venmo PERSON
# 70 million CARDINAL
# Friday DATE
# Bitcoin PERSON
# 50,000 MONEY
# first ORDINAL
# early March DATE
# Bitcoin PERSON
# a momentous year DATE
# 2020 DATE
# Musk PERSON
# Tesla PERSON
# Tesla PERSON
# first quarter DATE
# $438m MONEY
# 315 MONEY
# Bitcoin ORG
# Jack Dorsey PERSON
# Tuesday DATE
# Venmo PERSON
# Four CARDINAL
# chars]New York GPE
# CNN ORG
# Saturday DATE
# about 6% PERCENT
# nearly $58,000 MONEY
# a big year DATE
# Robinhood ORG
# today DATE
# Christine Brown PERSON
# Robinhoods PERSON
# Reuters ORG
# Reuters ORG
# Inc PERSON
# Monday DATE
# two CARDINAL
# Crusoe Energy ORG
# two CARDINAL
# today DATE
# Dogecoin GPE
# Reuters ORG
# April 12 DATE
# Reuters ORG
# Monday DATE
# Dorsey PERSON
# Twitter PRODUCT
# Wednesday DATE
# Elon Musk PERSON
# BBC ORG
# Kuber PERSON
# India GPE
# Thursday DATE
# $25 million MONEY
# Indi GPE
# Reuters ORG
# Santa Clarita GPE
# California GPE
# U.S. GPE
# October 2, 2019 DATE
# Mike Blake
#  PERSON
# Reuters ORG
# $27 million MONEY
# Reuters ORG
# LONDON GPE
# April 13 DATE
# Reuters ORG
# 62,575 MONEY
# Tuesday DATE
# 2021 DATE
# Reuters ORG
# Bitcoin PERSON
# March 15, 2021 DATE
# Bitcoin PERSON
# Marseille GPE
# France GPE
# February 7, 2021 DATE
# Eric GaillardBitcoin PERSON
# 6.54% PERCENT
# 57,098.08 MONEY
# Friday DATE
# 3,504.11 MONEY
# Reuters ORG
# April 24 DATE
# Reuters ORG
# 1.77% PERCENT
# 50,269.9 MONEY
# Saturday DATE
# 906.75 MONEY
# Bitcoin PERSON
# 22.5 CARDINAL
# Bitcoin PERSON
# April 24, 2020 DATE
# 1.77% PERCENT
# Reuters ORG
# April 18 DATE
# Reuters ORG
# 7.7% PERCENT
# 55,408.08 MONEY
# Sunday DATE
# 4,624.21 MONEY
# Asian NORP
# Australia GPE
# NZ GPE
# South Korea GPE
# 0.4% PERCENT
# 14% PERCENT
# Sunday DATE
# early Monday DATE
# Reuters ORG
# Dec. 8, 2017 DATE
# Benoit Tessier/Illustration/File Photo
#  ORG
# Reuters ORG
# 24, 2021 DATE
# more than 25% PERCENT
# 2017 DATE
# Reuters ORG
# Bitcoin PERSON
# March 15, 2021 DATE
# Reuters ORG
# 1 CARDINAL
# Musk PERSON
# Bitcoin PERSON
# Tesla PERSON
# first quarter DATE
# Entrepreneur ORG
# Last year DATE
# the Great Depression EVENT
# first ORDINAL
# 27, 2021 DATE
# Entrepreneur ORG
# Bitcoin PERSON
# over 9% PERCENT
# 50,000 MONEY
# CoinDesk ORG
# Monday DATE
# DCENT ORG
# 105 MONEY
# April 21 DATE
# Cesc Maymo PERSON
# first ORDINAL
# North America LOC
# $1 billion MONEY
# just two months DATE
# the first quarter of 2021 DATE
# American NORP
# Coinbase NORP
# Coinbase ORG
# Bitcoin PERSON
# the Bitcoin Center New York City ORG
# New York's GPE
# July 28, 2015 DATE
# REUTERS ORG
# Brendan McDermidU.S. PERSON
# Tuesday DATE
# Roman Sterlingov PERSON
# Groot GPE
# Daily Crunch WORK_OF_ART
# April 23, 2021 DATE
# Meet Disney Imagineering ORG
# Global Inc ORG
# Wednesday DATE
# $99.6 billion MONEY
# Reuters ORG
# April 6 DATE
# Reuters ORG
# Hindenburg Research ORG
# Tuesday DATE
# Chinese NORP
# Ebang International Holdings Inc. ORG
# Ebang PERSON
# Bitcoin PERSON
# March 15, 2021 DATE
# Dado Ruvic/IllustrationBitcoin's PERSON
# Friday DATE
# U.S. GPE
# Joe Biden PERSON
# Bitcoin PERSON
# Bitcoin PERSON
# ETH ORG
# Litecoin (LTC ORG
# Bitcoin Cash PERSON
# ATM ORG
# 13, 2019 DATE
# Costa Mesa GPE
# Sean Culkin PERSON
# the Los Angeles Chargers ORG
# the Hoag Performance Center FAC
# Costa Mesa GPE
# California GPE
# April 21 DATE
# Reuters ORG
# Goldman Sachs ORG
# 64,000 MONEY
# first ORDINAL
# U.S. GPE
# as much as 15% PERCENT
# Sunday DATE
# just days DATE
# 64,869 MONEY
# about $56,440 MONEY
# 65,000 MONEY
# last week DATE
# U.S. GPE
# 28, 2021 DATE
# Tesla ORG
# Bitcoin PERSON
# the first quarter of 2021 DATE
# the Wall Street Jour ORG
# Santa Clarita GPE
# California GPE
# U.S. GPE
# October 2, 2019 DATE
# Mike BlakeTesla Inc PERSON
# Wednesday DATE
# one-month DATE
# Monday DATE
# Reuters ORG
# MicroStrategy Inc ORG
# Reuters ORG
# more than 4% PERCENT
# Wednesday DATE
# 60,000 MONEY
# Sellers PERSON
# 60,000 MONEY
# Ord/Getty Images ORG
# Bitcoin PERSON
# Fundstrat PERSON
# Tom Lee PERSON
# Wednesday DATE
# thousands CARDINAL
# recent weeks DATE
# the start of April DATE
# 41% PERCENT
# April DATE
# 8% PERCENT
# as much as 8% PERCENT
# Monday DATE
# five straight days DATE
# almost a fifth CARDINAL
# earlier this month DATE
# Bit PERSON
# Reuters ORG
# SINGAPORE GPE
# May 3 DATE
# Reuters ORG
# Monday DATE
# 3,000 MONEY
# Bitcoin PERSON
# ETH ORG
# Litecoin (LTC ORG
# Bitcoin Cash PERSON
# ATM ORG
# Bitcoin Fund ORG
# Canadian NORP
# 3iQ CARDINAL
# Singapore GPE
# U.S. GPE
# Middle East LOC
# DUBAI PERSON
# April 20 DATE
# Reute ORG
# 65,000 MONEY
# Dado Ruvic PERSON
# Reuters ORG
# The Securities and Exchange Commission ORG
# Wednesday DATE
# Musk PERSON
# Tesla PERSON
# Pool/Getty Images ORG
# Bitcoin PERSON
# two-month DATE
# Tuesday DATE
# Elon Musk's PERSON
# chars]Today DATE
# Coinbase NORP
# 250 MONEY
# Coinbase NORP
# 381 MONEY
# today DATE
# around 52% percent PERCENT
# the Bitcoin Fund ORG
# Nasdaq Dubai PERSON
# the Middle East's LOC
# first ORDINAL
# Reuters ORG
# Reuters ORG
# Global Inc PERSON
# more than $91 billion MONEY
# Wednesday DATE
# first ORDINAL
# weekly DATE
# eight CARDINAL
# Bitcoin PERSON
# nearly seven weeks DATE
# Friday DATE
# U.S. GPE
# Bitcoin PERSON
# January 8, 2021 DATE
# Dado RuvicLondon's PERSON
# High Court ORG
# Bitcoin PERSON
# March 15, 2021 DATE
# Dado Ruvic/IllustrationInflows PERSON
# Reuters ORG
# Reuters ORG
# Hindenburg Research ORG
# Tuesday DATE
# Ebang International Holdings Inc ORG
# Chinese NORP
# Reuters ORG
# April 13 DATE
# Reuters ORG
# 36% PERCENT
# Wednesday DATE
# Bitcoin PERSON
# March 15, 2021 DATE
# British NORP
# weekly DATE
# CoinShares ORG
# Asian NORP
# two days DATE
# Australia GPE
# NZ GPE
# Chinese NORP
# one-month DATE
# German NORP
# Frankfurt GPE
# Germany GPE
# April 14, 2021 DATE
# REUTERS/Staff/File PhotoWorld ORG
# five-day DATE
# Reuters ORG
# April 28 DATE
# Reuters ORG
# $27 million MONEY
# Wednesday DATE
# Friday DATE
# 1% PERCENT
# earlier this week DATE
# nearly seven weeks DATE
# U.S. GPE
# February 19, 2021 DATE
# Dado Ruvic/IllustrationCryptocurrency PERSON
# Reuters ORG
# February 19, 2021 DATE
# SINGAPORE GPE
# Novogratz GPE
# Galaxy Digital ORG
# Rick Wilking PERSON
# Mike Novogratz PERSON
# chars]NEW YORK GPE
# Reuters ORG
# $4.9 billion MONEY
# April 16 DATE
# the first two weeks of the month DATE
# Bitcoin PERSON
# 2012 DATE
# Bitcoin PERSON
# Porzycki/NurPhoto ORG
# Getty Images ORG
# Tokyo GPE
# Nexon ORG
# Wednesday DATE
# $100 million MONEY
# above $60,000 MONEY
# first ORDINAL
# March DATE
# Saturday DATE
# Sunday DATE
# 59.604.06 MONEY
# Spanish NORP
# AI ORG
# Entrepreneur ORG
# the summer DATE
# Entrepreneur ORG
# Bitcoin PERSON
# 22, 2021 DATE
# Spanish NORP
# AI ORG
# Entrepreneur ORG
# 26, 2021 DATE
# Spanish NORP
# AI ORG
# Reuters ORG
# U.S. GPE
# Wednesday DATE
# BNY Mellon ORG
# Thursday DATE
# XRP ORG
# Yuriko Nakao PERSON
# Bitcoin PERSON
# 47,000 MONEY
# HSBC InvestDirect ORG
# MicroStrategy ORG
# late April DATE
# mid-month DATE
# around $64,000 MONEY
# Sunday DATE
# 47,600 MONEY
# over 25% PERCENT
# less than two weeks DATE
# American Express ORG
# Getty Images ORG
# Tuesday DATE
# Katie Stockton PERSON
# Stockton PERSON
# Reuters ORG
# SINGAPORE GPE
# May 3 DATE
# Reuters ORG
# Monday DATE
# 3,000 MONEY
# last weeks DATE
# Europe LOC
# Reuters ORG
# Litecoin PERSON
# February 14, 2018 DATE
# REUTERS/Dad ORG
# Bitcoin PERSON
# $2 trillion MONEY
# first ORDINAL
# earlier this week DATE
# Bitcoin  PERSON
# 18 CARDINAL
# A few years ago DATE
# Tesla PERSON
# Those days DATE
# 36.32 MONEY
# April 3 DATE
# 90% PERCENT
# Founder PERSON
# Brian Armstrong PERSON
# Steven Ferdman PERSON
# Wednesday DATE
# Reuters ORG
# FILE PERSON
# January 29, 2021 DATE
# REUTERS ORG
# Brendan McDermid/Illustration PERSON
# Reuters ORG
# Robinhood ORG
# Monday DATE
# Argentina GPE
# eight-year DATE
# 210 CARDINAL
# Megaw ORG
# Chris Larsen PERSON
# YouTube ORG
# Chris Larsen PERSON
# Ripp PERSON

# %% [markdown]
# ---

# %% [markdown]
# ## Ethereum NER

# %%
# Concatenate all of the bitcoin text together
ethereum_text= ethereum_df["text"].str.cat()
#ethereum_text

# %%
# Run the NER processor on all of the text
ethereum_ner = nlp(ethereum_text)

# Add a title to the document
ethereum_ner.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(ethereum_ner, style = 'ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Cryptocurrency continues to gain mainstream acceptance, as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PayPal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  announced that they have added
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin, Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin Cash
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Litecoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to its
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Venmo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  app. With a user base of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     70 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>The social payment service announced on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that its customers can now buy, hold, and sell cryptocurrencies within the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Venmo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  cr… [+1524
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chars]New York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Business)Bitcoin prices continued their rebound
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Saturday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , rising
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about 6%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly $58,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# . But the world's largest cryptocurrency has been overshadowed lately by its younger sibling, … [+866 chars]ConsenSys, a key player in crypto and a major proponent of the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  blockchain, has raised a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $65 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  funding round from
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     J.P. Morgan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mastercard
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UBS AG
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , as well as major blockchain compan… [+8767 chars]A representation of virtual currency Ethereum are seen in front of a stock graph in this illustration taken
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     February 19, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . REUTERS/
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dado Ruvic/IllustrationCryptocurrency
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  ether hit a record high of… [+760 chars]By
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>FILE PHOTO: A representation of virtual currency Ethereum are seen in front of a stock graph in this illustration taken
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     February 19, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-

# %%
# List all Entities
for ent in ethereum_ner.ents:
    print(ent.text, ent.label_)
# Out:
# PayPal ORG
# Bitcoin, Ethereum ORG
# Bitcoin Cash PERSON
# Litecoin PERSON
# Venmo PERSON
# 70 million CARDINAL
# Tuesday DATE
# Venmo PERSON
# Four CARDINAL
# chars]New York GPE
# CNN ORG
# Saturday DATE
# about 6% PERCENT
# nearly $58,000 MONEY
# Ethereum ORG
# $65 million MONEY
# J.P. Morgan PERSON
# Mastercard PERSON
# UBS AG ORG
# February 19, 2021 DATE
# Dado Ruvic/IllustrationCryptocurrency PERSON
# Reuters ORG
# February 19, 2021 DATE
# SINGAPORE GPE
# a big year DATE
# Robinhood ORG
# today DATE
# Christine Brown PERSON
# Robinhoods PERSON
# Reuters ORG
# SINGAPORE GPE
# May 3 DATE
# Reuters ORG
# Monday DATE
# 3,000 MONEY
# last weeks DATE
# Europe LOC
# Reuters ORG
# SINGAPORE GPE
# May 3 DATE
# Reuters ORG
# Monday DATE
# 3,000 MONEY
# Topps GPE
# first ORDINAL
# NFT ORG
# 23, 2021 DATE
# Spanish NORP
# AI ORG
# Bitcoin PERSON
# 27, 2021 DATE
# Entrepreneur ORG
# this year DATE
# one CARDINAL
# Year after year DATE
# Friday DATE
# Bitcoin PERSON
# 50,000 MONEY
# first ORDINAL
# early March DATE
# Bitcoin PERSON
# 36.32 MONEY
# April 3 DATE
# 90% PERCENT
# as much as 8% PERCENT
# Tuesday DATE
# Coinbase ORG
# Berlin GPE
# April 14 DATE
# hours TIME
# Beeple’s ORG
# $69 million MONEY
# NFT ORG
# 24 CARDINAL
# 24 CARDINAL
# Ethereum PERSON
# Images/Getty Images ORG
# above $2,400 MONEY
# Thursday DATE
# $100 billion MONEY
# MLB ORG
# NFT ORG
# Major League Baseball ORG
# NFT ORG
# Topps GPE
# 11 years DATE
# later this year DATE
# Longevica PERSON
# $13 million MONEY
# 16th April 2021 DATE
# The Art Newspaper ORG
# CNN ORG
# Reuters ORG
# April 18 DATE
# Reuters ORG
# 7.7% PERCENT
# 55,408.08 MONEY
# Sunday DATE
# 4,624.21 MONEY
# Apple ORG
# Amazon ORG
# iPad ORG
# Ethereum ORG
# Dado Ruvic PERSON
# Reuters ORG
# Friday DATE
# 60,000.</li MONEY
# DCENT ORG
# 105 MONEY
# April 21 DATE
# NFT ORG
# Disaster Girl WORK_OF_ART
# NFT ORG
# over $500,000 MONEY
# Foundation ORG
# Disaster Girl' ORG
# the kilowatt-hour TIME
# one CARDINAL
# about 12 cents MONEY
# Reuters ORG
# April 24 DATE
# Reuters ORG
# 1.77% PERCENT
# 50,269.9 MONEY
# Saturday DATE
# 906.75 MONEY
# Bitcoin PERSON
# 22.5 CARDINAL
# Ruvic/Reuters ORG
# as much as 8.5% PERCENT
# Thursday DATE
# above $2,560 MONEY
# $300 billion MONEY
# first ORDINAL
# 26, 2021 DATE
# this year DATE
# Bitcoin, Ethereum ORG
# Dogecoin GPE
# Coinba PERSON
# BNY Mellon ORG
# Thursday DATE
# XRP ORG
# Yuriko Nakao PERSON
# Bitcoin PERSON
# 47,000 MONEY
# Entrepreneur ORG
# Decentralized PERSON
# 2020s DATE
# Last year's DATE
# April 28 DATE
# Reuters ORG
# The European Investment Bank ORG
# 100 million CARDINAL
# $121 million MONEY
# two-year DATE
# Reuters ORG
# Bitcoin PERSON
# Marseille GPE
# France GPE
# February 7, 2021 DATE
# Eric GaillardBitcoin PERSON
# 6.54% PERCENT
# 57,098.08 MONEY
# Friday DATE
# 3,504.11 MONEY
# Bitcoin PERSON
# April 24, 2020 DATE
# 1.77% PERCENT
# nine-week DATE
# Thursday DATE
# U.S. Treasury ORG
# the first quarter DATE
# Bitcoin PERSON
# $2 trillion MONEY
# first ORDINAL
# earlier this week DATE
# Bitcoin  PERSON
# +3648 chars]April MONEY
# 27, 2021 DATE
# Entrepreneur ORG
# Bitcoin PERSON
# over 9% PERCENT
# 50,000 MONEY
# CoinDesk ORG
# Monday DATE
# Bitcoin PERSON
# March 15, 2021 DATE
# Dado Ruvic/IllustrationInflows PERSON
# weekly DATE
# CoinShares ORG
# chars]NEW YORK GPE
# Reuters ORG
# $4.9 billion MONEY
# April 16 DATE
# the first two weeks of the month DATE
# as much as 8% PERCENT
# Monday DATE
# five straight days DATE
# almost a fifth CARDINAL
# earlier this month DATE
# Bit PERSON
# NFT ORG
# Ethereum ORG
# two CARDINAL
# Entrepreneur ORG
# Bitcoin PERSON
# Huang PERSON
# 2017 DATE
# first ORDINAL
# Deutsche Bank ORG
# Nomura ORG
# New Y GPE
# Brendan McDermid PERSON
# Dow ORG
# 500 CARDINAL
# Thursday DATE
# weekly DATE
# more than 70 million CARDINAL
# the next few weeks DATE
# Venmo PERSON
# just four CARDINAL
# 1990 DATE
# millions of dollars MONEY
# above $2,700 MONEY
# Kraken ORG
# Kraken ORG
# Pete Humiston PERSON
# Chris Larsen PERSON
# YouTube ORG
# Chris Larsen PERSON
# Ripp PERSON
# Cuban NORP
# Brian Snyder PERSON
# Reuters ORG
# Mark Cuban PERSON
# $1 million MONEY
# Netflix ORG
# Amazon ORG
# $1 million MONEY
# 35% PERCENT
# March DATE
# Kraken ORG
# Dado Ruvic PERSON
# Reuters ORG
# above $2,700 MONEY
# Bitcoin and Ethereum ORG
# Bitcoin PERSON
# March 15, 2021 DATE
# Dado Ruvic/IllustrationBitcoin's PERSON
# >Edward Snowden PERSON
# NFT ORG
# NFT ORG
# Edward Snowden PERSON
# April 21 DATE
# Reuters ORG
# Goldman Sachs ORG
# American Express ORG
# second ORDINAL
# 3,000 MONEY
# first ORDINAL
# Sunday DATE
# Sunday night TIME
# ETHUSD ORG
# +2.09% PERCENT
# 3,035 MONEY
# years-long DATE
# winter DATE
# 23, 2021 DATE
# recent months DATE
# 2012 DATE
# Reuters ORG
# April 13 DATE
# Reuters ORG
# ConsenSys ORG
# Tuesday DATE
# $65 million MONEY
# J.P. Morgan PERSON
# Mastercard PERSON
# captionZoë Roth's PERSON
# Dave PERSON
# 2005 DATE
# Disaster Girl WORK_OF_ART
# 473,000 MONEY
# 341,000 MONEY
# Zoë Ro PERSON
# first ORDINAL
# this weeks DATE
# NFL ORG
# Trevor Lawrence PERSON
# Gatorade PRODUCT
# -0.30% PERCENT
# 13, 2021 DATE
# Entrepreneur ORG
# A century ago DATE
# French NORP
# Marcel Duchamp PERSON
# 1917 DATE
# 28, 2021 DATE
# Spanish NORP
# AI ORG
# 24, 2021 DATE
# more than 25% PERCENT
# 16, 2021 DATE
# Entrepreneur ORG
# Bitcoin, Ethereum ORG
# year DATE
# FOM ORG
# more than 4% PERCENT
# Wednesday DATE
# 60,000 MONEY
# Sellers PERSON
# 60,000 MONEY
# Tuesday DATE
# Tuesday DATE
# last month DATE
# this month DATE
# as much as 70% PERCENT
# February DATE
# Bloomberg GPE
# Reuters ORG
# U.S. GPE
# fourth ORDINAL
# weekly DATE
# Friday DATE
# the Federal Reserve ORG
# Golden State Warriors ORG
# NFT ORG
# Tuesday DATE
# first ORDINAL
# Nakao/Getty Images
# Wall Street Bets ORG
# only last week DATE
# Discus PERSON
# Venmo PERSON
# Photo Illustration PERSON
# Getty Images ORG
# PayPal PERSON
# Venmo PERSON
# one hundred dollar MONEY
# Seoul GPE
# February 7, 2011 DATE
# Lee Jae-WonThe PERSON
# U.S. GPE
# fourth ORDINAL
# weekly DATE
# U.S. GPE
# fourth ORDINAL
# weekly DATE
# Friday DATE
# the Federal Reserve ORG
# German NORP
# PayPal PERSON
# Europarc Dreilinden GPE
# Berlin GPE
# Kleinmachnow GPE
# Germany GPE
# August 6, 2019 DATE
# U.S. GPE
# Fed ORG
# Updates GPE
# U.S. GPE
# afternoon TIME
# NEW YORK GPE
# April 6 DATE
# Reuters ORG
# U.S. GPE
# two-week DATE
# chars]NEW YORK GPE
# Reuters ORG
# a record $4.5 billion MONEY
# the first quarter DATE
# 20, 2021 DATE
# Entrepreneur ORG
# Coinbase NORP
# second ORDINAL
# Friday DATE
# above $2,000 MONEY
# +4.12% PERCENT
# nearly 7% PERCENT
# around $2,069 MONEY
# American Express ORG
# second ORDINAL
# Thursday DATE
# $100 billion MONEY
# New Constructs ORG
# David Trainer PERSON
# recent weeks DATE
# the start of April DATE
# 41% PERCENT
# April DATE
# 8% PERCENT
# 29, 2021 DATE
# Entrepreneur ORG
# Decentralized Finance ORG
# DeFi ORG
# 15, 2021 DATE
# Spanish NORP
# AI ORG
# Wednesday DATE
# Coinbase NORP
# today DATE
# one CARDINAL
# hundreds of millions of dollars MONEY
# Gab Bois‘ GPE
# over 500,000 CARDINAL
# first ORDINAL
# ICANN ORG
# Bitcoin…
#  ORG
# first ORDINAL
# Friday DATE
# 1% PERCENT
# earlier this week DATE
# nearly seven weeks DATE
# U.S. GPE
# MSCI PERSON
# this June 20, 2017 DATE
# Thomas White/Illustration/File PhotoAsian PERSON
# Wednesday DATE
# Asian NORP
# Fed ORG
# one hundred dollar MONEY
# Seoul GPE
# February 7, 2011 DATE
# Lee Jae-WonThe PERSON
# U.S. GPE
# fourth ORDINAL
# weekly DATE
